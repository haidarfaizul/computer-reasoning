# %%
from IPython import get_ipython
from IPython.display import display

# %%
# !pip install pandas requests beautifulsoup4 pdfminer.six lxml > /dev/null 2>&1

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import argparse
import io
import os
import re
import time
import urllib
from concurrent.futures import ThreadPoolExecutor, wait
from datetime import date
import pandas as pd
import requests
from bs4 import BeautifulSoup
from pdfminer import high_level

# %% [markdown]
# # Seleksi & Unduh

# %%
def create_path(folder_name):
    path = os.path.join(os.getcwd(), folder_name)
    if not os.path.exists(path):
        os.makedirs(path)
    return path

# %%
def open_page(link):
    count = 0
    while count < 3:
        try:
            return BeautifulSoup(requests.get(link).text, "lxml")
        except:
            count += 1
            time.sleep(5)

def get_detail(soup, keyword):
    try:
        text = (
            soup.find(lambda tag: tag.name == "td" and keyword in tag.text)
            .find_next()
            .get_text()
            .strip()
        )
        return text
    except:
        return ""

def get_pdf(url, path_pdf):
    file = urllib.request.urlopen(url)
    file_name = file.info().get_filename().replace("/", " ")
    file_content = file.read()
    with open(f"{path_pdf}/{file_name}", "wb") as out_file:
        out_file.write(file_content)
    return io.BytesIO(file_content), file_name

# %%
def clean_text(text):
    text = text.replace("M a h ka m a h A g u n g R e p u blik In d o n esia\n", "")
    text = text.replace("Disclaimer\n", "")
    text = text.replace(
        "Kepaniteraan Mahkamah Agung Republik Indonesia berusaha untuk selalu mencantumkan informasi paling kini dan akurat sebagai bentuk komitmen Mahkamah Agung untuk pelayanan publik, transparansi dan akuntabilitas\n",
        "",
    )
    text = text.replace(
        "pelaksanaan fungsi peradilan. Namun dalam hal-hal tertentu masih dimungkinkan terjadi permasalahan teknis terkait dengan akurasi dan keterkinian informasi yang kami sajikan, hal mana akan terus kami perbaiki dari waktu kewaktu.\n",
        "",
    )
    text = text.replace(
        "Dalam hal Anda menemukan inakurasi informasi yang termuat pada situs ini atau informasi yang seharusnya ada, namun belum tersedia, maka harap segera hubungi Kepaniteraan Mahkamah Agung RI melalui :\n",
        "",
    )
    text = text.replace(
        "Email : kepaniteraan@mahkamahagung.go.id    Telp : 021-384 3348 (ext.318)\n",
        "",
    )
    return text

# %%
def is_url_already_scraped(url, destination):
    """
    Checks if a URL has already been scraped and saved in the CSV file.

    Args:
        url (str): The URL to check.
        destination (str): The path to the output CSV file.

    Returns:
        bool: True if the URL exists in the CSV, False otherwise.
    """
    if not os.path.isfile(f"{destination}.csv"):
      return False

    try:
        df = pd.read_csv(f"{destination}.csv")
        return url in df["link"].values
    except pd.errors.EmptyDataError:
      return False

# %%
def extract_data(link, keyword_url):
    global today
    global path_output
    global path_pdf
    global download_pdf

    path_output = '/content/drive/MyDrive/Tugasbesar/CSV'
    path_pdf = '/content/drive/MyDrive/Tugasbesar/PDF'
    today = date.today().strftime("%Y-%m-%d")

    keyword_url = keyword_url.replace("/", " ")
    if keyword_url.startswith("https"):
        keyword_url = ""
    destination = f"{path_output}/putusan_ma_{keyword_url}_{today}"

    if is_url_already_scraped(link, destination):
        print(f"Skipping duplicate URL: {link}")
        return

    soup = open_page(link)
    table = soup.find("table", {"class": "table"})
    judul = table.find("h2").text
    table.find("h2").decompose()

    nomor = get_detail(table, "Nomor")
    tingkat_proses = get_detail(table, "Tingkat Proses")
    klasifikasi = get_detail(table, "Klasifikasi")
    kata_kunci = get_detail(table, "Kata Kunci")
    tahun = get_detail(table, "Tahun")
    tanggal_register = get_detail(table, "Tanggal Register")
    lembaga_peradilan = get_detail(table, "Lembaga Peradilan")
    jenis_lembaga_peradilan = get_detail(table, "Jenis Lembaga Peradilan")
    hakim_ketua = get_detail(table, "Hakim Ketua")
    hakim_anggota = get_detail(table, "Hakim Anggota")
    panitera = get_detail(table, "Panitera")
    amar = get_detail(table, "Amar")
    amar_lainnya = get_detail(table, "Amar Lainnya")
    catatan_amar = get_detail(table, "Catatan Amar")
    tanggal_musyawarah = get_detail(table, "Tanggal Musyawarah")
    tanggal_dibacakan = get_detail(table, "Tanggal Dibacakan")
    kaidah = get_detail(table, "Kaidah")
    abstrak = get_detail(table, "Abstrak")

    try:
        link_pdf = soup.find("a", href=re.compile(r"/pdf/"))["href"]
        file_pdf, file_name_pdf = get_pdf(link_pdf, path_pdf)
        text_pdf = high_level.extract_text(file_pdf)
        text_pdf = clean_text(text_pdf)
    except:
        link_pdf = ""
        text_pdf = ""
        file_name_pdf = ""

    data = [
        judul,
        nomor,
        tingkat_proses,
        klasifikasi,
        kata_kunci,
        tahun,
        tanggal_register,
        lembaga_peradilan,
        jenis_lembaga_peradilan,
        hakim_ketua,
        hakim_anggota,
        panitera,
        amar,
        amar_lainnya,
        catatan_amar,
        tanggal_musyawarah,
        tanggal_dibacakan,
        kaidah,
        abstrak,
        link,
        link_pdf,
        file_name_pdf,
        text_pdf,
    ]
    result = pd.DataFrame(
        [data],
        columns=[
            "judul",
            "nomor",
            "tingkat_proses",
            "klasifikasi",
            "kata_kunci",
            "tahun",
            "tanggal_register",
            "lembaga_peradilan",
            "jenis_lembaga_peradilan",
            "hakim_ketua",
            "hakim_anggota",
            "panitera",
            "amar",
            "amar_lainnya",
            "catatan_amar",
            "tanggal_musyawarah",
            "tanggal_dibacakan",
            "kaidah",
            "abstrak",
            "link",
            "link_pdf",
            "file_name_pdf",
            "text_pdf",
        ],
    )

    print(destination)
    if not os.path.isfile(f"{destination}.csv"):
        result.to_csv(f"{destination}.csv", header=True, index=False)
    else:
        result.to_csv(f"{destination}.csv", mode="a", header=False, index=False)

# %%
def run_scraper(keyword=None, url=None, sort_date=True, download_pdf=True):
    if not keyword and not url:
        print("Please provide a keyword or URL")
        return

    path_output = '/content/drive/MyDrive/Tugasbesar/CSV'
    path_pdf = '/content/drive/MyDrive/Tugasbesar/PDF'

    today = date.today().strftime("%Y-%m-%d")

    link = f"https://putusan3.mahkamahagung.go.id/search.html?q={keyword}&page=1"

    if url:
        link = url

    soup = open_page(link)

    last_page = int(
        soup.find_all("a", {"class": "page-link"})[-1].get("data-ci-pagination-page")
    )

    if url:
        print(f"Scraping with url: {url} - {20 * last_page} data - {last_page} page")
    else:
        print(f"Scraping with keyword: {keyword} - {20 * last_page} data - {last_page} page")

    if url:
        keyword_url = url
    else:
        keyword_url = keyword

    futures = []
    with ThreadPoolExecutor(max_workers=4) as executor:
        for page in range(last_page):
            futures.append(
                executor.submit(run_process, keyword_url, page + 1, sort_date)
            )
    wait(futures)

def run_process(keyword_url, page, sort_page):
    if keyword_url.startswith("https"):
        link = f"{keyword_url}&page={page}"
    else:
        link = f"https://putusan3.mahkamahagung.go.id/search.html?q={keyword_url}&page={page}"
    if sort_page:
        link = f"{link}&obf=TANGGAL_PUTUS&obm=desc"

    print(link)

    soup = open_page(link)
    links = soup.find_all("a", {"href": re.compile("/direktori/putusan")})

    for link in links:
        extract_data(link["href"], keyword_url)

def scrape_specific_url(url, download_pdf=True):
    if not url or not url.startswith("https://"):
        print("Please provide a valid URL")
        return

    path_output = '/content/drive/MyDrive/Tugasbesar/CSV'
    path_pdf = '/content/drive/MyDrive/Tugasbesar/PDF'
    today = date.today().strftime("%Y-%m-%d")

    extract_data(url, url, path_output, path_pdf, today)

# %%
run_scraper(url="https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=2e43da4ffbd3f7803cb80cce91ad8866&jd=&court=097471PN87&t_put=2024&t_reg=&t_upl=&t_pr=&tp=0")
# Out:
# Scraping with url: https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=2e43da4ffbd3f7803cb80cce91ad8866&jd=&court=097471PN87&t_put=2024&t_reg=&t_upl=&t_pr=&tp=0 - 180 data - 9 page

# %% [markdown]
# # Konversi & ekstrasi teks

# %%
# !pip install pdfminer.six
# Out:
# Collecting pdfminer.six
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (3.4.2)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.11/dist-packages (from pdfminer.six) (43.0.3)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=36.0.0->pdfminer.six) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six) (2.22)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 58.8 MB/s eta 0:00:00
# Installing collected packages: pdfminer.six
# Successfully installed pdfminer.six-20250506

# %%
import os
path_pdf = '/content/drive/MyDrive/Tugasbesar/PDF'
output_folder = '/content/drive/MyDrive/Tugasbesar/data/raw'

os.makedirs(output_folder, exist_ok=True)

# %%
from pdfminer.high_level import extract_text

def convert_pdf_to_txt(pdf_path, txt_path):
    try:
        text = extract_text(pdf_path)
        with open(txt_path, 'w', encoding='utf-8') as f:
            f.write(text)
        print(f'✅ Berhasil konversi: {txt_path}')
    except Exception as e:
        print(f'❌ Gagal konversi {pdf_path}: {e}')

# %%
for i, filename in enumerate(sorted(os.listdir(path_pdf))):
    if filename.endswith('.pdf'):
        pdf_path = os.path.join(path_pdf, filename)
        txt_filename = f'case_{i+1:03}.txt'
        txt_path = os.path.join(output_folder, txt_filename)
        convert_pdf_to_txt(pdf_path, txt_path)
# Out:
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_001.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_002.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_003.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_004.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_005.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_006.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_007.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_008.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_009.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_010.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_011.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_012.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_013.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_014.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_015.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_016.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_017.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_018.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_019.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_020.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_021.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_022.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_023.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_024.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_025.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_026.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_027.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_028.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_029.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_030.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_031.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_032.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_033.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_034.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_035.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_036.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_037.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_038.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_039.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_040.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_041.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_042.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_043.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_044.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_045.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_046.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_047.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_048.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_049.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_050.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_051.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_052.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_053.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_054.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_055.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_056.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_057.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_058.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_059.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_060.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_061.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_062.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_063.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_064.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_065.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_066.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_067.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_068.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_069.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_070.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_071.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_072.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_073.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_074.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_075.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_076.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_077.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_078.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_079.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_080.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_081.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_082.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_083.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_084.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_085.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_086.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_087.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_088.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_089.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_090.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_091.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_092.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_093.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_094.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_095.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_096.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_097.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_098.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_099.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_100.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_101.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_102.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_103.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_104.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_105.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_106.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_107.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_108.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_109.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_110.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_111.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_112.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_113.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_114.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_115.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_116.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_117.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_118.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_119.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_120.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_121.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_122.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_123.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_124.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_125.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_126.txt
# ✅ Berhasil konversi: /content/drive/MyDrive/Tugasbesar/data/raw/case_127.txt

# %% [markdown]
# # cleaning

# %%
import os
import re

# Fungsi pembersih
def bersihkan_teks(teks):
    teks = re.sub(r'putusan\.?mahkamahagung\.?go\.?id', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'disclaimer.*?kami sajikan.*?(?=\s|$)', '', teks, flags=re.IGNORECASE | re.DOTALL)
    teks = re.sub(r'kepaniteraan@mahkamahagung\.?go\.?id', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'telp.*?\d{3}.*?(?=\s|$)', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\bhalaman\s*\d+\b', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\bhalaman\b', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\d+\s*dari\s*\d+\s*halaman', '', teks, flags=re.IGNORECASE)
    teks = re.sub(r'\s+', ' ', teks)
    teks = teks.lower().strip()
    return teks

# Folder input & output
input_folder = '/content/drive/MyDrive/Tugasbesar/data/raw'
output_folder = '/content/drive/MyDrive/Tugasbesar/data_clean/raw'
os.makedirs(output_folder, exist_ok=True)

# Loop semua file .txt
for filename in sorted(os.listdir(input_folder)):
    if filename.endswith('.txt'):
        input_path = os.path.join(input_folder, filename)
        output_path = os.path.join(output_folder, filename)

        with open(input_path, 'r', encoding='utf-8') as f:
            teks = f.read()

        teks_bersih = bersihkan_teks(teks)

        with open(output_path, 'w', encoding='utf-8') as f:
            f.write(teks_bersih)

        print(f"✅ Dibersihkan dan disimpan: {filename}")
# Out:
# ✅ Dibersihkan dan disimpan: case_001.txt
# ✅ Dibersihkan dan disimpan: case_002.txt
# ✅ Dibersihkan dan disimpan: case_003.txt
# ✅ Dibersihkan dan disimpan: case_004.txt
# ✅ Dibersihkan dan disimpan: case_005.txt
# ✅ Dibersihkan dan disimpan: case_006.txt
# ✅ Dibersihkan dan disimpan: case_007.txt
# ✅ Dibersihkan dan disimpan: case_008.txt
# ✅ Dibersihkan dan disimpan: case_009.txt
# ✅ Dibersihkan dan disimpan: case_010.txt
# ✅ Dibersihkan dan disimpan: case_011.txt
# ✅ Dibersihkan dan disimpan: case_012.txt
# ✅ Dibersihkan dan disimpan: case_013.txt
# ✅ Dibersihkan dan disimpan: case_014.txt
# ✅ Dibersihkan dan disimpan: case_015.txt
# ✅ Dibersihkan dan disimpan: case_016.txt
# ✅ Dibersihkan dan disimpan: case_017.txt
# ✅ Dibersihkan dan disimpan: case_018.txt
# ✅ Dibersihkan dan disimpan: case_019.txt
# ✅ Dibersihkan dan disimpan: case_020.txt
# ✅ Dibersihkan dan disimpan: case_021.txt
# ✅ Dibersihkan dan disimpan: case_022.txt
# ✅ Dibersihkan dan disimpan: case_023.txt
# ✅ Dibersihkan dan disimpan: case_024.txt
# ✅ Dibersihkan dan disimpan: case_025.txt
# ✅ Dibersihkan dan disimpan: case_026.txt
# ✅ Dibersihkan dan disimpan: case_027.txt
# ✅ Dibersihkan dan disimpan: case_028.txt
# ✅ Dibersihkan dan disimpan: case_029.txt
# ✅ Dibersihkan dan disimpan: case_030.txt
# ✅ Dibersihkan dan disimpan: case_031.txt
# ✅ Dibersihkan dan disimpan: case_032.txt
# ✅ Dibersihkan dan disimpan: case_033.txt
# ✅ Dibersihkan dan disimpan: case_034.txt
# ✅ Dibersihkan dan disimpan: case_035.txt
# ✅ Dibersihkan dan disimpan: case_036.txt
# ✅ Dibersihkan dan disimpan: case_037.txt
# ✅ Dibersihkan dan disimpan: case_038.txt
# ✅ Dibersihkan dan disimpan: case_039.txt
# ✅ Dibersihkan dan disimpan: case_040.txt
# ✅ Dibersihkan dan disimpan: case_041.txt
# ✅ Dibersihkan dan disimpan: case_042.txt
# ✅ Dibersihkan dan disimpan: case_043.txt
# ✅ Dibersihkan dan disimpan: case_044.txt
# ✅ Dibersihkan dan disimpan: case_045.txt
# ✅ Dibersihkan dan disimpan: case_046.txt
# ✅ Dibersihkan dan disimpan: case_047.txt
# ✅ Dibersihkan dan disimpan: case_048.txt
# ✅ Dibersihkan dan disimpan: case_049.txt
# ✅ Dibersihkan dan disimpan: case_050.txt
# ✅ Dibersihkan dan disimpan: case_051.txt
# ✅ Dibersihkan dan disimpan: case_052.txt
# ✅ Dibersihkan dan disimpan: case_053.txt
# ✅ Dibersihkan dan disimpan: case_054.txt
# ✅ Dibersihkan dan disimpan: case_055.txt
# ✅ Dibersihkan dan disimpan: case_056.txt
# ✅ Dibersihkan dan disimpan: case_057.txt
# ✅ Dibersihkan dan disimpan: case_058.txt
# ✅ Dibersihkan dan disimpan: case_059.txt
# ✅ Dibersihkan dan disimpan: case_060.txt
# ✅ Dibersihkan dan disimpan: case_061.txt
# ✅ Dibersihkan dan disimpan: case_062.txt
# ✅ Dibersihkan dan disimpan: case_063.txt
# ✅ Dibersihkan dan disimpan: case_064.txt
# ✅ Dibersihkan dan disimpan: case_065.txt
# ✅ Dibersihkan dan disimpan: case_066.txt
# ✅ Dibersihkan dan disimpan: case_067.txt
# ✅ Dibersihkan dan disimpan: case_068.txt
# ✅ Dibersihkan dan disimpan: case_069.txt
# ✅ Dibersihkan dan disimpan: case_070.txt
# ✅ Dibersihkan dan disimpan: case_071.txt
# ✅ Dibersihkan dan disimpan: case_072.txt
# ✅ Dibersihkan dan disimpan: case_073.txt
# ✅ Dibersihkan dan disimpan: case_074.txt
# ✅ Dibersihkan dan disimpan: case_075.txt
# ✅ Dibersihkan dan disimpan: case_076.txt
# ✅ Dibersihkan dan disimpan: case_077.txt
# ✅ Dibersihkan dan disimpan: case_078.txt
# ✅ Dibersihkan dan disimpan: case_079.txt
# ✅ Dibersihkan dan disimpan: case_080.txt
# ✅ Dibersihkan dan disimpan: case_081.txt
# ✅ Dibersihkan dan disimpan: case_082.txt
# ✅ Dibersihkan dan disimpan: case_083.txt
# ✅ Dibersihkan dan disimpan: case_084.txt
# ✅ Dibersihkan dan disimpan: case_085.txt
# ✅ Dibersihkan dan disimpan: case_086.txt
# ✅ Dibersihkan dan disimpan: case_087.txt
# ✅ Dibersihkan dan disimpan: case_088.txt
# ✅ Dibersihkan dan disimpan: case_089.txt
# ✅ Dibersihkan dan disimpan: case_090.txt
# ✅ Dibersihkan dan disimpan: case_091.txt
# ✅ Dibersihkan dan disimpan: case_092.txt
# ✅ Dibersihkan dan disimpan: case_093.txt
# ✅ Dibersihkan dan disimpan: case_094.txt
# ✅ Dibersihkan dan disimpan: case_095.txt
# ✅ Dibersihkan dan disimpan: case_096.txt
# ✅ Dibersihkan dan disimpan: case_097.txt
# ✅ Dibersihkan dan disimpan: case_098.txt
# ✅ Dibersihkan dan disimpan: case_099.txt
# ✅ Dibersihkan dan disimpan: case_100.txt
# ✅ Dibersihkan dan disimpan: case_101.txt
# ✅ Dibersihkan dan disimpan: case_102.txt
# ✅ Dibersihkan dan disimpan: case_103.txt
# ✅ Dibersihkan dan disimpan: case_104.txt
# ✅ Dibersihkan dan disimpan: case_105.txt
# ✅ Dibersihkan dan disimpan: case_106.txt
# ✅ Dibersihkan dan disimpan: case_107.txt
# ✅ Dibersihkan dan disimpan: case_108.txt
# ✅ Dibersihkan dan disimpan: case_109.txt
# ✅ Dibersihkan dan disimpan: case_110.txt
# ✅ Dibersihkan dan disimpan: case_111.txt
# ✅ Dibersihkan dan disimpan: case_112.txt
# ✅ Dibersihkan dan disimpan: case_113.txt
# ✅ Dibersihkan dan disimpan: case_114.txt
# ✅ Dibersihkan dan disimpan: case_115.txt
# ✅ Dibersihkan dan disimpan: case_116.txt
# ✅ Dibersihkan dan disimpan: case_117.txt
# ✅ Dibersihkan dan disimpan: case_118.txt
# ✅ Dibersihkan dan disimpan: case_119.txt
# ✅ Dibersihkan dan disimpan: case_120.txt
# ✅ Dibersihkan dan disimpan: case_121.txt
# ✅ Dibersihkan dan disimpan: case_122.txt
# ✅ Dibersihkan dan disimpan: case_123.txt
# ✅ Dibersihkan dan disimpan: case_124.txt
# ✅ Dibersihkan dan disimpan: case_125.txt
# ✅ Dibersihkan dan disimpan: case_126.txt
# ✅ Dibersihkan dan disimpan: case_127.txt

# %% [markdown]
# # Validasi

# %%
import os
import re
from datetime import datetime

# Konfigurasi direktori
source_dir = '/content/drive/MyDrive/Tugasbesar/data/raw'
target_dir = '/content/drive/MyDrive/Tugasbesar/data_clean/raw'
log_file_path = '/content/drive/MyDrive/Tugasbesar/logs/cleaning.log'

# Membuat direktori log jika diperlukan
os.makedirs(os.path.dirname(log_file_path), exist_ok=True)

def analyze_text_files():
    """Fungsi untuk membandingkan file teks asli dan hasil pembersihan"""
    with open(log_file_path, 'w', encoding='utf-8') as log:
        # Header log
        log.write(f"Laporan Proses Pembersihan Teks\nTanggal: {datetime.now()}\n\n")
        log.write(f"{'Nama File':<20} {'Asli':<8} {'Bersih':<8} {'%':<8} {'Status'}\n")
        log.write('-' * 55 + '\n')

        # Proses setiap file
        for file in sorted(os.listdir(source_dir)):
            if file.endswith('.txt'):
                source_file = os.path.join(source_dir, file)
                target_file = os.path.join(target_dir, file)

                try:
                    # Membaca konten file
                    with open(source_file, 'r', encoding='utf-8') as src:
                        original_content = src.read()

                    with open(target_file, 'r', encoding='utf-8') as tgt:
                        cleaned_content = tgt.read()

                    # Menghitung perbandingan
                    original_size = len(original_content)
                    cleaned_size = len(cleaned_content)
                    similarity = (cleaned_size / original_size * 100) if original_size > 0 else 0

                    # Menentukan status
                    file_status = "✅ Baik" if similarity >= 80 else "⚠️ Perlu Periksa"

                    log.write(f"{file:<20} {original_size:<8} {cleaned_size:<8} {similarity:<7.1f}% {file_status}\n")

                except Exception as error:
                    log.write(f"{file:<20} ERROR: {str(error)}\n")

if __name__ == '__main__':
    analyze_text_files()
